# %% [markdown]
# # Module 2 Summative Lab
#
# ## Introduction
#
# For today's section, we're going to work on a single big lab to apply everything we've learned in Module 2!
#
# ## About This Lab
#
# A quick note before getting started--this lab isn't like other labs you seen so far. This lab is meant to take ~8 hours to complete, so it's much longer and more challenging that the average labs you've seen so far. If you feel like this lab is challenging or that you might be struggling a bit, don't fret--that's by design! With everything we've learned about Web Scraping, APIs, and Databases, the best way to test our knowledge of it is to build something substantial!
#
# ## The Project
#
# In this lab, we're going to make use of everything we've learned about APIs, databases, and Object-Oriented Programming to **_Extract, Transform, and Load_** (or **_ETL_**, for short) some data from a SQL database into a MongoDB Database.
#
# You'll find a database containing information about soccer teams and the matches they've played in the file `database.sqlite`. For this project, our goal is to get the data we think is important from this SQL database, do some calculations and data transformation, and then store everything in a MongoDB database.
#
# Let's get into the specifics of this project.
#
# ### The Goal
#
# Start by examining the data dictionary for the SQL database we'll be working with, which comes from this [kaggle page](https://www.kaggle.com/laudanum/footballdelphi).  Familiarize yourself with the tables it contains, and what each column means. We'll be using this database to get data on each soccer team, calculate some summary statistics, and then store each in a MongoDB database.
#
# Upon completion of this lab, each unique team in this dataset should have a record in the MongoDB instance containing the following information:
#
# * The name of the team
# * The total number of goals scored by the team during the 2011 season
# * The total number of wins the team earned during the 2011 season
# * A histogram visualization of the team's wins and losses for the 2011 season (store the visualization directly)
# * The team's win percentage on days where it was raining during games in the 2011 season.
#
# #### Getting the Weather Data
#
# Note that for this last calculation, you'll need to figure out if it was raining or not during the game. The database itself does not contain this information, but it does contain the date on which the game was played. For this, you'll need to use the [DarkSky API](https://darksky.net/dev) to get the historical weather data for that day. Note that each game is played in a different location, and this information is not contained in our SQL database. However, the teams in this database are largely german, so go ahead and just use the weather in Berlin, Germany as a proxy for this information. If it was raining in Berlin on the day the game was played, count that as rain game--**_you do not need to try and figure out the actual weather at each game's location, because we don't have that information!_**
#
# #### NOTE: The DarkSky API is limited to 1000 free API calls a day, so be sure to test your model on very small samples. Otherwise, you'll hit the rate limit!
#
# ## Project Architecture
#
# Unlike previous labs, this lab is more open-ended, and will require you to make design decisions and plan out your strategy for building a system with this many working parts. However, **_using Object-Oriented Programming is a requirement for this project--you must create at least 2 separate, well structured classes in your solution!_** Although it may seem easier to "just start coding", this is a classic beginner's mistake. Instead, think about separating out the different functionalities you'll need to reach your goal, and then build classes to handle each. For instance, at minimum, you'll need to:
#
# * Query the SQL database
# * Calculate summary statistics
# * Get the weather data from the DarkSky API
# * Load the data into MongoDB
#
# We **_strongly recommend_** you consider creating separate classes for handling at least some of these of these tasks.  Be sure to plan the inputs, outputs, and methods for each class before you begin coding!
#
# **_NOTE:_** We have provided some empty classes below. You are welcome to delete them and use a different architecture for this project if you so choose.  You do not have to use each of them, they are just there to give you an idea of what you could sorts of classes you may want to consider using.
#
# ### Rapid Prototyping and Refactoring
#
# It's totally okay to try to get a task working without using OOP. For instance, when experimenting with the DarkSky API for getting historical weather data, it makes sense to just write the code in the cells and rapidly iterate until you get it all working. However, once you get it working, you're not done--you should then **_Refactor_** your code into functions or classes to make your code more modular, reusable, understandable, and maintainable!
#
# In short--do what you need to do to get each separate piece of functionality working, and then refactor it into a class after you've figured it out!
#
# ### Some Final Advice
#
# You haven't built anything this big or complex thus far, so you may not yet fully realize how much trial and error goes into it. If your code keeps breaking, resist the urge to get frustrated, and just keep working. Software development is an iterative process!  No one writes perfect code that works the first time for something this involved. You're going to run into _a lot_ of small errors in this project, right up until the point where it just works, and then you're done! However, you can reduce these errors by planning out your code, and thinking about how all of the pieces fit together before you begin coding. Once you have some basic understanding of how it all will work, then you'll know what you need to build, and then all that is left is to build it!
#
# In short:
#
# * Plan ahead--you'll thank yourself later!
# * Errors and broken code aren't bad, they're normal.
# * Keep working, and stay confident--you can do this!
#
# Good luck--we look forward to seeing your completed project!

# %% [markdown]
# # Summary

# %% [markdown]
# ## Database information

# %% [markdown]
# ![tables](tables.png)

# %% [markdown]
# ### Table: Matches
#
# Match_ID (int): unique ID per match
# Div (str): identifies the division the match was played in (D1 = Bundesliga, D2 = Bundesliga 2, E0 = English Premier League)
#
# Season (int): Season the match took place in (usually covering the period of August till May of the following year)
#
# Date (str): Date of the match
#
# HomeTeam (str): Name of the home team
#
# AwayTeam (str): Name of the away team
#
# FTHG (int) (Full Time Home Goals): Number of goals scored by the home team
#
# FTAG (int) (Full Time Away Goals): Number of goals scored by the away team
#
# FTR (str) (Full Time Result): 3-way result of the match (H = Home Win, D = Draw, A = Away Win)
#
# ### Table: Teams
#
# Season (str): Football season for which the data is valid
#
# TeamName (str): Name of the team the data concerns
#
# KaderHome (str): Number of Players in the squad
#
# AvgAgeHome (str): Average age of players
#
# ForeignPlayersHome (str): Number of foreign players (non-German, non-English respectively) playing for the team
#
# OverallMarketValueHome (str): Overall market value of the team pre-season in EUR (based on data from transfermarkt.de)
#
# AvgMarketValueHome (str): Average market value (per player) of the team pre-season in EUR (based on data from transfermarkt.de)
#
# StadiumCapacity (str): Maximum stadium capacity of the team's home stadium
#
# ### Table: Unique Teams
#
# TeamName (str): Name of a team
#
# Unique_Team_ID (int): Unique identifier for each team
#
# ### Table: Teams_in_Matches
#
# Match_ID (int): Unique match ID
#
# Unique_Team_ID (int): Unique team ID (This table is used to easily retrieve each match a given team has played in)

# %% [markdown]
# ## Links
# https://www.kaggle.com/laudanum/footballdelphi
#
# https://darksky.net/dev

# %% [markdown]
# ## Notes

# %% [markdown]
# Upon completion of this lab, each unique team in this dataset should have a record in the MongoDB instance containing the following information:
#
# * The name of the team
# * The total number of goals scored by the team during the 2011 season
# * The total number of wins the team earned during the 2011 season
# * A histogram visualization of the team's wins and losses for the 2011 season (store the visualization directly)
# * The team's win percentage on days where it was raining during games in the 2011 season.
#
# Use the weather in Berlin, Germany.
# The DarkSky API is limited to 1000 free API calls a day.
#
# You must create at least 2 separate, well structured classes in your solution.
#
# * Query the SQL database
# * Calculate summary statistics
# * Get the weather data from the DarkSky API
# * Load the data into MongoDB

# %%
class Matches:
    def __init__(self):
        self.matches_df = None
        self.rain_dict = {}
        self.summary_list = []
        self.all_teams = []
    
    def check_matches_for_rain(self, darksky, load_from_pickle_file=False):
        import pickle
        if not load_from_pickle_file:
            unique_dates = self.matches_df["Date"].unique()
            for i, date in enumerate(unique_dates):
                print(float(i)/len(unique_dates), date)
                self.rain_dict[date] = did_it_rain_in_berlin(darksky, date)
            pickle.dump(self.rain_dict, open('rain_dict.pkl', 'wb'))
        else:
            self.rain_dict = pickle.load(open('rain_dict.pkl', 'rb'))
    
    def add_rained_to_matches_df(self, darksky, load_rain_from_pickle_file=False):
        self.check_matches_for_rain(darksky, load_from_pickle_file=load_rain_from_pickle_file)
        self.matches_df["Rained"] = self.matches_df["Date"].apply(lambda x: self.rain_dict[x])
    
    def get_list_of_teams(self):
        self.all_teams = list(set(list(self.matches_df["HomeTeam"])+list(self.matches_df["AwayTeam"])))
    
    def compute_summary_list_of_dicts(self):
        self.get_list_of_teams()
        for team in self.all_teams:
            home_goals = self.matches_df[self.matches_df["HomeTeam"] == team]["FTHG"].sum()
            away_goals = self.matches_df[self.matches_df["AwayTeam"] == team]["FTAG"].sum()
            goals_scored = home_goals + away_goals
            home_wins = len(self.matches_df[(self.matches_df["HomeTeam"] == team) & (self.matches_df["FTR"] == "H")])
            away_wins = len(self.matches_df[(self.matches_df["AwayTeam"] == team) & (self.matches_df["FTR"] == "A")])
            total_wins = home_wins + away_wins
            home_losses = len(self.matches_df[(self.matches_df["HomeTeam"] == team) & (self.matches_df["FTR"] == "A")])
            away_losses = len(self.matches_df[(self.matches_df["AwayTeam"] == team) & (self.matches_df["FTR"] == "H")])
            total_losses = home_losses + away_losses
            raining_df = self.matches_df[self.matches_df["Rained"]]
            raining_games = len(raining_df[(raining_df["HomeTeam"] == team) | (raining_df["AwayTeam"] == team)])
            if raining_games > 0:
                raining_home_wins = len(raining_df[(raining_df["HomeTeam"] == team) & (raining_df["FTR"] == "H")])
                raining_away_wins = len(raining_df[(raining_df["AwayTeam"] == team) & (raining_df["FTR"] == "A")])
                raining_wins = raining_home_wins + raining_away_wins
                raining_win_percentage = float(raining_wins)/float(raining_games)
            else:
                raining_win_percentage = 'N/A (played no games in the rain)'
            self.summary_list.append({'name': team, 'goals_scored': str(goals_scored), 'total_wins': str(total_wins), 
                                  'total_losses': str(total_losses), 'raining_win_percentage': str(raining_win_percentage)})
    
    def get_matches_for_year(self, year):
        self.matches_df = sql_query_to_df(self.cursor, """SELECT * FROM Matches""")
        self.matches_df = self.matches_df[self.matches_df["Date"].str.contains(str(year))]
        
    def get_matches_for_season(self, cursor, year):
        starting_season_date_string = str(year)+'-08-01'
        ending_season_date_string = str(year+1)+'-05-31'
        starting_season_time = get_time_from_date_string(starting_season_date_string)
        ending_season_time = get_time_from_date_string(ending_season_date_string)
        self.matches_df = sql_query_to_df(cursor, """SELECT * FROM Matches""")
        match_times = self.matches_df["Date"].apply(lambda x: get_time_from_date_string(x))
        self.matches_df = self.matches_df[(starting_season_time <  match_times) &\
                                       (ending_season_time > match_times)]
        
    def get_summary_list(self):
        return self.summary_list

class MongoHandler:
    def __init__(self, database_name, collection_name):
        self.database_name = database_name
        self.collection_name = collection_name
        self.get_mongo_collection()
        
    def get_mongo_client(self):
        import pymongo
        self.myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")      
        
    def get_mongo_db(self):
        import pymongo
        self.get_mongo_client()
        self.mydb = self.myclient[self.database_name]
        
    def get_mongo_collection(self):
        import pymongo
        self.get_mongo_db()
        self.mycollection = self.mydb[self.collection_name]
    
    def mongo_display_collection_contents(self):
        query = self.mycollection.find({})
        for item in query:
            print(item)
            
    def insert_list(self, list_to_insert):
        self.mycollection.insert_many(list_to_insert)
        
    

class SQLHandler():
    def __init__(self, database_file_name):
        self.database_file_name = database_file_name
        self.connect_to_sql_database()
    
    def connect_to_sql_database(self):
        import sqlite3
        self.connection = sqlite3.connect(self.database_file_name)
        self.cursor = self.connection.cursor()
    
    def get_all_tables_from_sql_database(self):
        df = sql_query_to_df(self.cursor, """SELECT 
                                        name
                                    FROM 
                                        sqlite_master 
                                    WHERE 
                                        type ='table' AND 
                                        name NOT LIKE 'sqlite_%';""")
        return df
    
    def sql_query_to_list_of_dicts(self, sql_query, list_of_cols=None):
        import pandas as pd
        self.cursor.execute(sql_query)
        df = pd.DataFrame(self.cursor.fetchall())
        df.columns = [x[0] for x in c.description]
        list_of_dicts = convert_df_to_list_of_dicts(df, list_of_cols=list_of_cols)
        return list_of_dicts
    
    def get_cursor(self):
        return self.cursor

class DarkSkyHandler():
    def __init__(self, apikeyfilename="DARKSKYAPIKEY"):
        self.apikeyfilename = apikeyfilename
        self.get_darksky_api_key()
        
    def get_darksky_api_key(self):
        with open(self.apikeyfilename, 'r') as f:
            self.api_key = f.readlines()[0].strip()
            
def get_weather(darksky, lat, lon, date_string):
    import requests
    time_to_request = get_time_from_date_string(date_string)
    url = f"https://api.darksky.net/forecast/{darksky.api_key}/{lat},{lon},{time_to_request}"
    response = requests.get(url)
    return response

def get_weather_in_berlin(darsky, date_string):
    return get_weather(darksky, 52.520645, 13.409779, date_string)

def did_it_rain_in_berlin(darksky, date_string):
    response = get_weather_in_berlin(darksky, date_string)
    rained = "precipType" in response.json()['daily']['data'][0].keys() and \
    response.json()['daily']['data'][0]["precipType"] == "rain"
    return rained

def get_time_from_date_string(date_string):
    import datetime, time
    date_time_obj = datetime.datetime.strptime(date_string, '%Y-%m-%d')
    time_to_return = int(time.mktime(date_time_obj.timetuple()))
    return time_to_return

def convert_df_to_list_of_dicts(df, list_of_cols=None):
    list_of_dicts = []
    if list_of_cols == None:
        for i in range(len(df)):
            list_of_dicts.append(df.iloc[i,:].to_dict())
    else:
        for i in range(len(df)):
            list_of_dicts.append(df.iloc[i,list_of_cols].to_dict())
    return list_of_dicts

def sql_query_to_df(cursor, sql_query):
    import pandas as pd
    cursor.execute(sql_query)
    df = pd.DataFrame(cursor.fetchall())
    df.columns = [x[0] for x in cursor.description]
    return df

# %%
sql = SQLHandler('database.sqlite')
matches = Matches()
darksky = DarkSkyHandler()
mongo = MongoHandler("test5_database", "test5_collection")

# %%
matches.get_matches_for_season(sql.get_cursor(), 2011)
matches.add_rained_to_matches_df(darksky, load_rain_from_pickle_file=False)
matches.compute_summary_list_of_dicts()
summary_list = matches.get_summary_list()
mongo.insert_list(summary_list)
mongo.mongo_display_collection_contents()
# Out:
# 0.0 2012-03-31
# 0.006369426751592357 2011-12-11
# 0.012738853503184714 2011-08-13
# 0.01910828025477707 2011-11-27
# 0.025477707006369428 2012-02-18
# 0.03184713375796178 2012-01-20
# 0.03821656050955414 2012-02-04
# 0.044585987261146494 2012-04-21
# 0.050955414012738856 2011-09-18
# 0.05732484076433121 2011-10-23
# 0.06369426751592357 2011-10-01
# 0.07006369426751592 2012-03-03
# 0.07643312101910828 2011-08-27
# 0.08280254777070063 2012-03-17
# 0.08917197452229299 2011-11-06
# 0.09554140127388536 2012-05-05
# 0.10191082802547771 2012-04-11
# 0.10828025477707007 2011-12-17
# 0.11464968152866242 2012-02-03
# 0.12101910828025478 2011-10-29
# 0.12738853503184713 2012-01-22
# 0.1337579617834395 2011-12-03
# 0.14012738853503184 2012-04-14
# 0.1464968152866242 2012-03-25
# 0.15286624203821655 2012-03-10
# 0.1592356687898089 2012-04-07
# 0.16560509554140126 2011-11-19
# 0.17197452229299362 2011-10-14
# 0.17834394904458598 2011-09-24
# 0.18471337579617833 2012-04-28
# 0.1910828025477707 2011-12-18
# 0.19745222929936307 2012-03-02
# 0.20382165605095542 2012-03-16
# 0.21019108280254778 2012-02-17
# 0.21656050955414013 2011-08-06
# 0.2229299363057325 2011-11-04
# 0.22929936305732485 2011-09-16
# 0.2356687898089172 2012-05-06
# 0.24203821656050956 2012-02-11
# 0.2484076433121019 2011-10-02
# 0.25477707006369427 2012-03-30
# 0.2611464968152866 2011-10-22
# 0.267515923566879 2011-08-26
# 0.27388535031847133 2011-08-07
# 0.2802547770700637 2012-02-24
# 0.28662420382165604 2012-02-12
# 0.2929936305732484 2011-08-22
# 0.29936305732484075 2011-09-09
# 0.3057324840764331 2012-04-01
# 0.31210191082802546 2011-09-25
# 0.3184713375796178 2012-04-20
# 0.3248407643312102 2011-11-25
# 0.33121019108280253 2012-03-09
# 0.3375796178343949 2011-11-07
# 0.34394904458598724 2011-09-10
# 0.3503184713375796 2011-08-21
# 0.35668789808917195 2011-09-26
# 0.3630573248407643 2012-03-26
# 0.36942675159235666 2011-10-30
# 0.37579617834394907 2012-02-13
# 0.3821656050955414 2012-02-26
# 0.3885350318471338 2011-12-19
# 0.39490445859872614 2012-03-11
# 0.4012738853503185 2011-11-26
# 0.40764331210191085 2012-04-23
# 0.4140127388535032 2011-12-16
# 0.42038216560509556 2011-11-05
# 0.4267515923566879 2012-04-10
# 0.43312101910828027 2012-04-15
# 0.4394904458598726 2012-02-05
# 0.445859872611465 2012-03-04
# 0.45222929936305734 2011-09-17
# 0.4585987261146497 2012-01-21
# 0.46496815286624205 2012-03-18
# 0.4713375796178344 2012-04-22
# 0.47770700636942676 2011-08-20
# 0.4840764331210191 2012-02-10
# 0.49044585987261147 2012-02-25
# 0.4968152866242038 2011-12-10
# 0.5031847133757962 2012-01-29
# 0.5095541401273885 2011-10-16
# 0.5159235668789809 2011-08-05
# 0.5222929936305732 2012-03-23
# 0.5286624203821656 2011-09-23
# 0.535031847133758 2012-01-28
# 0.5414012738853503 2011-10-15
# 0.5477707006369427 2012-03-24
# 0.554140127388535 2011-11-18
# 0.5605095541401274 2012-04-29
# 0.5668789808917197 2011-12-09
# 0.5732484076433121 2012-04-08
# 0.5796178343949044 2012-03-12
# 0.5859872611464968 2011-10-28
# 0.5923566878980892 2012-01-27
# 0.5987261146496815 2011-12-04
# 0.6050955414012739 2011-09-11
# 0.6114649681528662 2011-09-30
# 0.6178343949044586 2012-02-19
# 0.6242038216560509 2012-04-13
# 0.6305732484076433 2011-10-21
# 0.6369426751592356 2011-08-14
# 0.643312101910828 2011-09-12
# 0.6496815286624203 2011-08-08
# 0.6560509554140127 2011-12-13
# 0.6624203821656051 2011-08-28
# 0.6687898089171974 2011-08-19
# 0.6751592356687898 2012-03-14
# 0.6815286624203821 2011-08-12
# 0.6878980891719745 2012-03-05
# 0.6942675159235668 2011-12-02
# 0.7006369426751592 2011-09-19
# 0.7070063694267515 2012-04-02
# 0.7133757961783439 2012-02-06
# 0.7197452229299363 2011-11-21
# 0.7261146496815286 2011-08-29
# 0.732484076433121 2012-04-05
# 0.7388535031847133 2011-11-28
# 0.7452229299363057 2011-12-12
# 0.7515923566878981 2011-11-20
# 0.7579617834394905 2012-02-27
# 0.7643312101910829 2011-10-31
# 0.7707006369426752 2012-02-20
# 0.7770700636942676 2011-10-17
# 0.7834394904458599 2011-12-05
# 0.7898089171974523 2012-04-16
# 0.7961783439490446 2011-10-03
# 0.802547770700637 2012-03-19
# 0.8089171974522293 2011-08-15
# 0.8152866242038217 2011-12-20
# 0.821656050955414 2011-12-21
# 0.8280254777070064 2011-12-22
# 0.8343949044585988 2011-12-26
# 0.8407643312101911 2011-12-27
# 0.8471337579617835 2011-12-30
# 0.8535031847133758 2011-12-31
# 0.8598726114649682 2012-01-01
# 0.8662420382165605 2012-01-02
# 0.8726114649681529 2012-01-03
# 0.8789808917197452 2012-01-04
# 0.8853503184713376 2012-01-11
# 0.89171974522293 2012-01-14
# 0.8980891719745223 2012-01-15
# 0.9044585987261147 2012-01-16
# 0.910828025477707 2012-01-31
# 0.9171974522292994 2012-02-01
# 0.9235668789808917 2012-03-13
# 0.9299363057324841 2012-03-20
# 0.9363057324840764 2012-03-21
# 0.9426751592356688 2012-04-06
# 0.9490445859872612 2012-04-09
# 0.9554140127388535 2012-04-24
# 0.9617834394904459 2012-04-30
# 0.9681528662420382 2012-05-01
# 0.9745222929936306 2012-05-02
# 0.9808917197452229 2012-05-07
# 0.9872611464968153 2012-05-08
# 0.9936305732484076 2012-05-13
# {'_id': ObjectId('5cddcf2df7a1b622be413dbf'), 'name': 'Hertha', 'goals_scored': '38', 'total_wins': '7', 'total_losses': '17', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc0'), 'name': 'Fortuna Dusseldorf', 'goals_scored': '61', 'total_wins': '15', 'total_losses': '4', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc1'), 'name': 'QPR', 'goals_scored': '43', 'total_wins': '10', 'total_losses': '21', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc2'), 'name': 'Ingolstadt', 'goals_scored': '43', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc3'), 'name': 'West Brom', 'goals_scored': '45', 'total_wins': '13', 'total_losses': '17', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc4'), 'name': 'Schalke 04', 'goals_scored': '74', 'total_wins': '20', 'total_losses': '10', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc5'), 'name': 'Kaiserslautern', 'goals_scored': '24', 'total_wins': '4', 'total_losses': '19', 'raining_win_percentage': '0.0'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc6'), 'name': 'Blackburn', 'goals_scored': '48', 'total_wins': '8', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc7'), 'name': 'Man City', 'goals_scored': '93', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.6875'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc8'), 'name': 'St Pauli', 'goals_scored': '56', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dc9'), 'name': 'Sunderland', 'goals_scored': '45', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dca'), 'name': 'Cottbus', 'goals_scored': '26', 'total_wins': '6', 'total_losses': '15', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dcb'), 'name': 'Nurnberg', 'goals_scored': '38', 'total_wins': '12', 'total_losses': '16', 'raining_win_percentage': '0.5555555555555556'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dcc'), 'name': 'Everton', 'goals_scored': '50', 'total_wins': '15', 'total_losses': '12', 'raining_win_percentage': '0.46153846153846156'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dcd'), 'name': 'Stuttgart', 'goals_scored': '63', 'total_wins': '15', 'total_losses': '11', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dce'), 'name': 'Duisburg', 'goals_scored': '39', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dcf'), 'name': 'Fulham', 'goals_scored': '48', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd0'), 'name': 'Aston Villa', 'goals_scored': '37', 'total_wins': '7', 'total_losses': '14', 'raining_win_percentage': '0.16666666666666666'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd1'), 'name': 'Hoffenheim', 'goals_scored': '41', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd2'), 'name': 'Leverkusen', 'goals_scored': '52', 'total_wins': '15', 'total_losses': '10', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd3'), 'name': 'Stoke', 'goals_scored': '36', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd4'), 'name': 'Mainz', 'goals_scored': '47', 'total_wins': '9', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd5'), 'name': 'Union Berlin', 'goals_scored': '54', 'total_wins': '14', 'total_losses': '13', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd6'), 'name': 'Liverpool', 'goals_scored': '47', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.4'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd7'), 'name': 'Chelsea', 'goals_scored': '65', 'total_wins': '18', 'total_losses': '10', 'raining_win_percentage': '0.6153846153846154'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd8'), 'name': 'Wigan', 'goals_scored': '42', 'total_wins': '11', 'total_losses': '17', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dd9'), 'name': 'Swansea', 'goals_scored': '44', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dda'), 'name': 'FC Koln', 'goals_scored': '39', 'total_wins': '8', 'total_losses': '20', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddcf2df7a1b622be413ddb'), 'name': 'Erzgebirge Aue', 'goals_scored': '30', 'total_wins': '7', 'total_losses': '15', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddcf2df7a1b622be413ddc'), 'name': 'Wolfsburg', 'goals_scored': '47', 'total_wins': '13', 'total_losses': '16', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413ddd'), 'name': 'Freiburg', 'goals_scored': '45', 'total_wins': '10', 'total_losses': '14', 'raining_win_percentage': '0.2727272727272727'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dde'), 'name': 'Karlsruhe', 'goals_scored': '30', 'total_wins': '8', 'total_losses': '18', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddcf2df7a1b622be413ddf'), 'name': 'Paderborn', 'goals_scored': '48', 'total_wins': '16', 'total_losses': '7', 'raining_win_percentage': '0.45454545454545453'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de0'), 'name': 'Ein Frankfurt', 'goals_scored': '72', 'total_wins': '19', 'total_losses': '6', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de1'), 'name': 'Bolton', 'goals_scored': '46', 'total_wins': '10', 'total_losses': '22', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de2'), 'name': 'Tottenham', 'goals_scored': '66', 'total_wins': '20', 'total_losses': '9', 'raining_win_percentage': '0.75'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de3'), 'name': 'Munich 1860', 'goals_scored': '59', 'total_wins': '16', 'total_losses': '10', 'raining_win_percentage': '0.6666666666666666'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de4'), 'name': 'Bayern Munich', 'goals_scored': '77', 'total_wins': '23', 'total_losses': '7', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de5'), 'name': 'Augsburg', 'goals_scored': '36', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.36363636363636365'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de6'), 'name': 'Man United', 'goals_scored': '89', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.8'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de7'), 'name': 'Arsenal', 'goals_scored': '74', 'total_wins': '21', 'total_losses': '10', 'raining_win_percentage': '0.5714285714285714'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de8'), 'name': 'Braunschweig', 'goals_scored': '32', 'total_wins': '8', 'total_losses': '9', 'raining_win_percentage': '0.375'}
# {'_id': ObjectId('5cddcf2df7a1b622be413de9'), 'name': 'Aachen', 'goals_scored': '30', 'total_wins': '6', 'total_losses': '13', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dea'), 'name': 'Greuther Furth', 'goals_scored': '67', 'total_wins': '19', 'total_losses': '3', 'raining_win_percentage': '0.5384615384615384'}
# {'_id': ObjectId('5cddcf2df7a1b622be413deb'), 'name': 'Norwich', 'goals_scored': '52', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dec'), 'name': "M'gladbach", 'goals_scored': '49', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddcf2df7a1b622be413ded'), 'name': 'Dresden', 'goals_scored': '48', 'total_wins': '12', 'total_losses': '12', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddcf2df7a1b622be413dee'), 'name': 'Wolves', 'goals_scored': '40', 'total_wins': '5', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddcf2df7a1b622be413def'), 'name': 'Frankfurt FSV', 'goals_scored': '42', 'total_wins': '7', 'total_losses': '12', 'raining_win_percentage': '0.07692307692307693'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df0'), 'name': 'Hannover', 'goals_scored': '41', 'total_wins': '12', 'total_losses': '10', 'raining_win_percentage': '0.4166666666666667'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df1'), 'name': 'Newcastle', 'goals_scored': '56', 'total_wins': '19', 'total_losses': '11', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df2'), 'name': 'Bochum', 'goals_scored': '40', 'total_wins': '9', 'total_losses': '16', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df3'), 'name': 'Werder Bremen', 'goals_scored': '49', 'total_wins': '11', 'total_losses': '14', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df4'), 'name': 'Dortmund', 'goals_scored': '80', 'total_wins': '25', 'total_losses': '3', 'raining_win_percentage': '0.6'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df5'), 'name': 'Hamburg', 'goals_scored': '35', 'total_wins': '8', 'total_losses': '14', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddcf2df7a1b622be413df6'), 'name': 'Hansa Rostock', 'goals_scored': '32', 'total_wins': '5', 'total_losses': '16', 'raining_win_percentage': '0.07142857142857142'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873ef5'), 'name': 'Ingolstadt', 'goals_scored': '43', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873ef6'), 'name': 'Union Berlin', 'goals_scored': '54', 'total_wins': '14', 'total_losses': '13', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873ef7'), 'name': 'Freiburg', 'goals_scored': '45', 'total_wins': '10', 'total_losses': '14', 'raining_win_percentage': '0.2727272727272727'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873ef8'), 'name': 'Hansa Rostock', 'goals_scored': '32', 'total_wins': '5', 'total_losses': '16', 'raining_win_percentage': '0.07142857142857142'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873ef9'), 'name': 'Duisburg', 'goals_scored': '39', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873efa'), 'name': 'Karlsruhe', 'goals_scored': '30', 'total_wins': '8', 'total_losses': '18', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873efb'), 'name': 'Man United', 'goals_scored': '89', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.8'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873efc'), 'name': 'Bolton', 'goals_scored': '46', 'total_wins': '10', 'total_losses': '22', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873efd'), 'name': 'Ein Frankfurt', 'goals_scored': '72', 'total_wins': '19', 'total_losses': '6', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873efe'), 'name': 'Sunderland', 'goals_scored': '45', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873eff'), 'name': 'Arsenal', 'goals_scored': '74', 'total_wins': '21', 'total_losses': '10', 'raining_win_percentage': '0.5714285714285714'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f00'), 'name': 'Bayern Munich', 'goals_scored': '77', 'total_wins': '23', 'total_losses': '7', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f01'), 'name': 'Leverkusen', 'goals_scored': '52', 'total_wins': '15', 'total_losses': '10', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f02'), 'name': 'Wolves', 'goals_scored': '40', 'total_wins': '5', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f03'), 'name': 'Aston Villa', 'goals_scored': '37', 'total_wins': '7', 'total_losses': '14', 'raining_win_percentage': '0.16666666666666666'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f04'), 'name': 'Wolfsburg', 'goals_scored': '47', 'total_wins': '13', 'total_losses': '16', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f05'), 'name': 'Wigan', 'goals_scored': '42', 'total_wins': '11', 'total_losses': '17', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f06'), 'name': 'Chelsea', 'goals_scored': '65', 'total_wins': '18', 'total_losses': '10', 'raining_win_percentage': '0.6153846153846154'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f07'), 'name': 'Munich 1860', 'goals_scored': '59', 'total_wins': '16', 'total_losses': '10', 'raining_win_percentage': '0.6666666666666666'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f08'), 'name': 'Augsburg', 'goals_scored': '36', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.36363636363636365'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f09'), 'name': 'Werder Bremen', 'goals_scored': '49', 'total_wins': '11', 'total_losses': '14', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0a'), 'name': 'Fulham', 'goals_scored': '48', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0b'), 'name': 'Dortmund', 'goals_scored': '80', 'total_wins': '25', 'total_losses': '3', 'raining_win_percentage': '0.6'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0c'), 'name': 'Fortuna Dusseldorf', 'goals_scored': '61', 'total_wins': '15', 'total_losses': '4', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0d'), 'name': 'Tottenham', 'goals_scored': '66', 'total_wins': '20', 'total_losses': '9', 'raining_win_percentage': '0.75'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0e'), 'name': 'Schalke 04', 'goals_scored': '74', 'total_wins': '20', 'total_losses': '10', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f0f'), 'name': 'Stuttgart', 'goals_scored': '63', 'total_wins': '15', 'total_losses': '11', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f10'), 'name': 'Swansea', 'goals_scored': '44', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f11'), 'name': 'Greuther Furth', 'goals_scored': '67', 'total_wins': '19', 'total_losses': '3', 'raining_win_percentage': '0.5384615384615384'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f12'), 'name': 'Stoke', 'goals_scored': '36', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f13'), 'name': 'Mainz', 'goals_scored': '47', 'total_wins': '9', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f14'), 'name': 'Braunschweig', 'goals_scored': '32', 'total_wins': '8', 'total_losses': '9', 'raining_win_percentage': '0.375'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f15'), 'name': 'Norwich', 'goals_scored': '52', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f16'), 'name': 'Hannover', 'goals_scored': '41', 'total_wins': '12', 'total_losses': '10', 'raining_win_percentage': '0.4166666666666667'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f17'), 'name': 'St Pauli', 'goals_scored': '56', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f18'), 'name': 'Hertha', 'goals_scored': '38', 'total_wins': '7', 'total_losses': '17', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f19'), 'name': 'Nurnberg', 'goals_scored': '38', 'total_wins': '12', 'total_losses': '16', 'raining_win_percentage': '0.5555555555555556'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1a'), 'name': 'West Brom', 'goals_scored': '45', 'total_wins': '13', 'total_losses': '17', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1b'), 'name': 'Man City', 'goals_scored': '93', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.6875'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1c'), 'name': 'Cottbus', 'goals_scored': '26', 'total_wins': '6', 'total_losses': '15', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1d'), 'name': 'Bochum', 'goals_scored': '40', 'total_wins': '9', 'total_losses': '16', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1e'), 'name': 'FC Koln', 'goals_scored': '39', 'total_wins': '8', 'total_losses': '20', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f1f'), 'name': 'Kaiserslautern', 'goals_scored': '24', 'total_wins': '4', 'total_losses': '19', 'raining_win_percentage': '0.0'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f20'), 'name': 'Frankfurt FSV', 'goals_scored': '42', 'total_wins': '7', 'total_losses': '12', 'raining_win_percentage': '0.07692307692307693'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f21'), 'name': "M'gladbach", 'goals_scored': '49', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f22'), 'name': 'Hamburg', 'goals_scored': '35', 'total_wins': '8', 'total_losses': '14', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f23'), 'name': 'Blackburn', 'goals_scored': '48', 'total_wins': '8', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f24'), 'name': 'Paderborn', 'goals_scored': '48', 'total_wins': '16', 'total_losses': '7', 'raining_win_percentage': '0.45454545454545453'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f25'), 'name': 'QPR', 'goals_scored': '43', 'total_wins': '10', 'total_losses': '21', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f26'), 'name': 'Aachen', 'goals_scored': '30', 'total_wins': '6', 'total_losses': '13', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f27'), 'name': 'Erzgebirge Aue', 'goals_scored': '30', 'total_wins': '7', 'total_losses': '15', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f28'), 'name': 'Everton', 'goals_scored': '50', 'total_wins': '15', 'total_losses': '12', 'raining_win_percentage': '0.46153846153846156'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f29'), 'name': 'Hoffenheim', 'goals_scored': '41', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f2a'), 'name': 'Newcastle', 'goals_scored': '56', 'total_wins': '19', 'total_losses': '11', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f2b'), 'name': 'Dresden', 'goals_scored': '48', 'total_wins': '12', 'total_losses': '12', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd1c6f7a1b62376873f2c'), 'name': 'Liverpool', 'goals_scored': '47', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.4'}
# {'_id': ObjectId('5cddd212f7a1b62376873f66'), 'name': 'Ingolstadt', 'goals_scored': '43', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddd212f7a1b62376873f67'), 'name': 'Union Berlin', 'goals_scored': '54', 'total_wins': '14', 'total_losses': '13', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd212f7a1b62376873f68'), 'name': 'Freiburg', 'goals_scored': '45', 'total_wins': '10', 'total_losses': '14', 'raining_win_percentage': '0.2727272727272727'}
# {'_id': ObjectId('5cddd212f7a1b62376873f69'), 'name': 'Hansa Rostock', 'goals_scored': '32', 'total_wins': '5', 'total_losses': '16', 'raining_win_percentage': '0.07142857142857142'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6a'), 'name': 'Duisburg', 'goals_scored': '39', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6b'), 'name': 'Karlsruhe', 'goals_scored': '30', 'total_wins': '8', 'total_losses': '18', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6c'), 'name': 'Man United', 'goals_scored': '89', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.8'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6d'), 'name': 'Bolton', 'goals_scored': '46', 'total_wins': '10', 'total_losses': '22', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6e'), 'name': 'Ein Frankfurt', 'goals_scored': '72', 'total_wins': '19', 'total_losses': '6', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f6f'), 'name': 'Sunderland', 'goals_scored': '45', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddd212f7a1b62376873f70'), 'name': 'Arsenal', 'goals_scored': '74', 'total_wins': '21', 'total_losses': '10', 'raining_win_percentage': '0.5714285714285714'}
# {'_id': ObjectId('5cddd212f7a1b62376873f71'), 'name': 'Bayern Munich', 'goals_scored': '77', 'total_wins': '23', 'total_losses': '7', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd212f7a1b62376873f72'), 'name': 'Leverkusen', 'goals_scored': '52', 'total_wins': '15', 'total_losses': '10', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddd212f7a1b62376873f73'), 'name': 'Wolves', 'goals_scored': '40', 'total_wins': '5', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd212f7a1b62376873f74'), 'name': 'Aston Villa', 'goals_scored': '37', 'total_wins': '7', 'total_losses': '14', 'raining_win_percentage': '0.16666666666666666'}
# {'_id': ObjectId('5cddd212f7a1b62376873f75'), 'name': 'Wolfsburg', 'goals_scored': '47', 'total_wins': '13', 'total_losses': '16', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f76'), 'name': 'Wigan', 'goals_scored': '42', 'total_wins': '11', 'total_losses': '17', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f77'), 'name': 'Chelsea', 'goals_scored': '65', 'total_wins': '18', 'total_losses': '10', 'raining_win_percentage': '0.6153846153846154'}
# {'_id': ObjectId('5cddd212f7a1b62376873f78'), 'name': 'Munich 1860', 'goals_scored': '59', 'total_wins': '16', 'total_losses': '10', 'raining_win_percentage': '0.6666666666666666'}
# {'_id': ObjectId('5cddd212f7a1b62376873f79'), 'name': 'Augsburg', 'goals_scored': '36', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.36363636363636365'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7a'), 'name': 'Werder Bremen', 'goals_scored': '49', 'total_wins': '11', 'total_losses': '14', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7b'), 'name': 'Fulham', 'goals_scored': '48', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7c'), 'name': 'Dortmund', 'goals_scored': '80', 'total_wins': '25', 'total_losses': '3', 'raining_win_percentage': '0.6'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7d'), 'name': 'Fortuna Dusseldorf', 'goals_scored': '61', 'total_wins': '15', 'total_losses': '4', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7e'), 'name': 'Tottenham', 'goals_scored': '66', 'total_wins': '20', 'total_losses': '9', 'raining_win_percentage': '0.75'}
# {'_id': ObjectId('5cddd212f7a1b62376873f7f'), 'name': 'Schalke 04', 'goals_scored': '74', 'total_wins': '20', 'total_losses': '10', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cddd212f7a1b62376873f80'), 'name': 'Stuttgart', 'goals_scored': '63', 'total_wins': '15', 'total_losses': '11', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cddd212f7a1b62376873f81'), 'name': 'Swansea', 'goals_scored': '44', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd212f7a1b62376873f82'), 'name': 'Greuther Furth', 'goals_scored': '67', 'total_wins': '19', 'total_losses': '3', 'raining_win_percentage': '0.5384615384615384'}
# {'_id': ObjectId('5cddd212f7a1b62376873f83'), 'name': 'Stoke', 'goals_scored': '36', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f84'), 'name': 'Mainz', 'goals_scored': '47', 'total_wins': '9', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd212f7a1b62376873f85'), 'name': 'Braunschweig', 'goals_scored': '32', 'total_wins': '8', 'total_losses': '9', 'raining_win_percentage': '0.375'}
# {'_id': ObjectId('5cddd212f7a1b62376873f86'), 'name': 'Norwich', 'goals_scored': '52', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddd212f7a1b62376873f87'), 'name': 'Hannover', 'goals_scored': '41', 'total_wins': '12', 'total_losses': '10', 'raining_win_percentage': '0.4166666666666667'}
# {'_id': ObjectId('5cddd212f7a1b62376873f88'), 'name': 'St Pauli', 'goals_scored': '56', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd212f7a1b62376873f89'), 'name': 'Hertha', 'goals_scored': '38', 'total_wins': '7', 'total_losses': '17', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8a'), 'name': 'Nurnberg', 'goals_scored': '38', 'total_wins': '12', 'total_losses': '16', 'raining_win_percentage': '0.5555555555555556'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8b'), 'name': 'West Brom', 'goals_scored': '45', 'total_wins': '13', 'total_losses': '17', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8c'), 'name': 'Man City', 'goals_scored': '93', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.6875'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8d'), 'name': 'Cottbus', 'goals_scored': '26', 'total_wins': '6', 'total_losses': '15', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8e'), 'name': 'Bochum', 'goals_scored': '40', 'total_wins': '9', 'total_losses': '16', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cddd212f7a1b62376873f8f'), 'name': 'FC Koln', 'goals_scored': '39', 'total_wins': '8', 'total_losses': '20', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cddd212f7a1b62376873f90'), 'name': 'Kaiserslautern', 'goals_scored': '24', 'total_wins': '4', 'total_losses': '19', 'raining_win_percentage': '0.0'}
# {'_id': ObjectId('5cddd212f7a1b62376873f91'), 'name': 'Frankfurt FSV', 'goals_scored': '42', 'total_wins': '7', 'total_losses': '12', 'raining_win_percentage': '0.07692307692307693'}
# {'_id': ObjectId('5cddd212f7a1b62376873f92'), 'name': "M'gladbach", 'goals_scored': '49', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cddd212f7a1b62376873f93'), 'name': 'Hamburg', 'goals_scored': '35', 'total_wins': '8', 'total_losses': '14', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cddd212f7a1b62376873f94'), 'name': 'Blackburn', 'goals_scored': '48', 'total_wins': '8', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd212f7a1b62376873f95'), 'name': 'Paderborn', 'goals_scored': '48', 'total_wins': '16', 'total_losses': '7', 'raining_win_percentage': '0.45454545454545453'}
# {'_id': ObjectId('5cddd212f7a1b62376873f96'), 'name': 'QPR', 'goals_scored': '43', 'total_wins': '10', 'total_losses': '21', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd212f7a1b62376873f97'), 'name': 'Aachen', 'goals_scored': '30', 'total_wins': '6', 'total_losses': '13', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd212f7a1b62376873f98'), 'name': 'Erzgebirge Aue', 'goals_scored': '30', 'total_wins': '7', 'total_losses': '15', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cddd212f7a1b62376873f99'), 'name': 'Everton', 'goals_scored': '50', 'total_wins': '15', 'total_losses': '12', 'raining_win_percentage': '0.46153846153846156'}
# {'_id': ObjectId('5cddd212f7a1b62376873f9a'), 'name': 'Hoffenheim', 'goals_scored': '41', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cddd212f7a1b62376873f9b'), 'name': 'Newcastle', 'goals_scored': '56', 'total_wins': '19', 'total_losses': '11', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cddd212f7a1b62376873f9c'), 'name': 'Dresden', 'goals_scored': '48', 'total_wins': '12', 'total_losses': '12', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cddd212f7a1b62376873f9d'), 'name': 'Liverpool', 'goals_scored': '47', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.4'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825410'), 'name': 'Stuttgart', 'goals_scored': '63', 'total_wins': '15', 'total_losses': '11', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825411'), 'name': 'Fortuna Dusseldorf', 'goals_scored': '61', 'total_wins': '15', 'total_losses': '4', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825412'), 'name': 'FC Koln', 'goals_scored': '39', 'total_wins': '8', 'total_losses': '20', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825413'), 'name': 'Wolfsburg', 'goals_scored': '47', 'total_wins': '13', 'total_losses': '16', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825414'), 'name': 'Fulham', 'goals_scored': '48', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825415'), 'name': 'Blackburn', 'goals_scored': '48', 'total_wins': '8', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825416'), 'name': 'Leverkusen', 'goals_scored': '52', 'total_wins': '15', 'total_losses': '10', 'raining_win_percentage': '0.42857142857142855'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825417'), 'name': 'Man City', 'goals_scored': '93', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.6875'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825418'), 'name': 'Hertha', 'goals_scored': '38', 'total_wins': '7', 'total_losses': '17', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825419'), 'name': 'Freiburg', 'goals_scored': '45', 'total_wins': '10', 'total_losses': '14', 'raining_win_percentage': '0.2727272727272727'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541a'), 'name': 'Bolton', 'goals_scored': '46', 'total_wins': '10', 'total_losses': '22', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541b'), 'name': 'Bayern Munich', 'goals_scored': '77', 'total_wins': '23', 'total_losses': '7', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541c'), 'name': 'Chelsea', 'goals_scored': '65', 'total_wins': '18', 'total_losses': '10', 'raining_win_percentage': '0.6153846153846154'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541d'), 'name': 'Norwich', 'goals_scored': '52', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.3'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541e'), 'name': 'Liverpool', 'goals_scored': '47', 'total_wins': '14', 'total_losses': '14', 'raining_win_percentage': '0.4'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82541f'), 'name': 'Ein Frankfurt', 'goals_scored': '72', 'total_wins': '19', 'total_losses': '6', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825420'), 'name': "M'gladbach", 'goals_scored': '49', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825421'), 'name': 'Hamburg', 'goals_scored': '35', 'total_wins': '8', 'total_losses': '14', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825422'), 'name': 'QPR', 'goals_scored': '43', 'total_wins': '10', 'total_losses': '21', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825423'), 'name': 'Stoke', 'goals_scored': '36', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825424'), 'name': 'Kaiserslautern', 'goals_scored': '24', 'total_wins': '4', 'total_losses': '19', 'raining_win_percentage': '0.0'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825425'), 'name': 'Paderborn', 'goals_scored': '48', 'total_wins': '16', 'total_losses': '7', 'raining_win_percentage': '0.45454545454545453'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825426'), 'name': 'Nurnberg', 'goals_scored': '38', 'total_wins': '12', 'total_losses': '16', 'raining_win_percentage': '0.5555555555555556'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825427'), 'name': 'St Pauli', 'goals_scored': '56', 'total_wins': '17', 'total_losses': '8', 'raining_win_percentage': '0.7272727272727273'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825428'), 'name': 'Greuther Furth', 'goals_scored': '67', 'total_wins': '19', 'total_losses': '3', 'raining_win_percentage': '0.5384615384615384'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825429'), 'name': 'Everton', 'goals_scored': '50', 'total_wins': '15', 'total_losses': '12', 'raining_win_percentage': '0.46153846153846156'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542a'), 'name': 'Frankfurt FSV', 'goals_scored': '42', 'total_wins': '7', 'total_losses': '12', 'raining_win_percentage': '0.07692307692307693'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542b'), 'name': 'Aachen', 'goals_scored': '30', 'total_wins': '6', 'total_losses': '13', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542c'), 'name': 'Munich 1860', 'goals_scored': '59', 'total_wins': '16', 'total_losses': '10', 'raining_win_percentage': '0.6666666666666666'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542d'), 'name': 'Hannover', 'goals_scored': '41', 'total_wins': '12', 'total_losses': '10', 'raining_win_percentage': '0.4166666666666667'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542e'), 'name': 'Aston Villa', 'goals_scored': '37', 'total_wins': '7', 'total_losses': '14', 'raining_win_percentage': '0.16666666666666666'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82542f'), 'name': 'Tottenham', 'goals_scored': '66', 'total_wins': '20', 'total_losses': '9', 'raining_win_percentage': '0.75'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825430'), 'name': 'Duisburg', 'goals_scored': '39', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825431'), 'name': 'Hoffenheim', 'goals_scored': '41', 'total_wins': '10', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825432'), 'name': 'Karlsruhe', 'goals_scored': '30', 'total_wins': '8', 'total_losses': '18', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825433'), 'name': 'Union Berlin', 'goals_scored': '54', 'total_wins': '14', 'total_losses': '13', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825434'), 'name': 'Sunderland', 'goals_scored': '45', 'total_wins': '11', 'total_losses': '15', 'raining_win_percentage': '0.3076923076923077'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825435'), 'name': 'Man United', 'goals_scored': '89', 'total_wins': '28', 'total_losses': '5', 'raining_win_percentage': '0.8'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825436'), 'name': 'Dresden', 'goals_scored': '48', 'total_wins': '12', 'total_losses': '12', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825437'), 'name': 'Newcastle', 'goals_scored': '56', 'total_wins': '19', 'total_losses': '11', 'raining_win_percentage': '0.23076923076923078'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825438'), 'name': 'Arsenal', 'goals_scored': '74', 'total_wins': '21', 'total_losses': '10', 'raining_win_percentage': '0.5714285714285714'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825439'), 'name': 'Werder Bremen', 'goals_scored': '49', 'total_wins': '11', 'total_losses': '14', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543a'), 'name': 'Schalke 04', 'goals_scored': '74', 'total_wins': '20', 'total_losses': '10', 'raining_win_percentage': '0.5'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543b'), 'name': 'West Brom', 'goals_scored': '45', 'total_wins': '13', 'total_losses': '17', 'raining_win_percentage': '0.2857142857142857'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543c'), 'name': 'Mainz', 'goals_scored': '47', 'total_wins': '9', 'total_losses': '13', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543d'), 'name': 'Cottbus', 'goals_scored': '26', 'total_wins': '6', 'total_losses': '15', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543e'), 'name': 'Braunschweig', 'goals_scored': '32', 'total_wins': '8', 'total_losses': '9', 'raining_win_percentage': '0.375'}
# {'_id': ObjectId('5cdec62df7a1b62d2a82543f'), 'name': 'Erzgebirge Aue', 'goals_scored': '30', 'total_wins': '7', 'total_losses': '15', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825440'), 'name': 'Wolves', 'goals_scored': '40', 'total_wins': '5', 'total_losses': '23', 'raining_win_percentage': '0.1'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825441'), 'name': 'Bochum', 'goals_scored': '40', 'total_wins': '9', 'total_losses': '16', 'raining_win_percentage': '0.2222222222222222'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825442'), 'name': 'Wigan', 'goals_scored': '42', 'total_wins': '11', 'total_losses': '17', 'raining_win_percentage': '0.3333333333333333'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825443'), 'name': 'Swansea', 'goals_scored': '44', 'total_wins': '12', 'total_losses': '15', 'raining_win_percentage': '0.2'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825444'), 'name': 'Ingolstadt', 'goals_scored': '43', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.15384615384615385'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825445'), 'name': 'Hansa Rostock', 'goals_scored': '32', 'total_wins': '5', 'total_losses': '16', 'raining_win_percentage': '0.07142857142857142'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825446'), 'name': 'Dortmund', 'goals_scored': '80', 'total_wins': '25', 'total_losses': '3', 'raining_win_percentage': '0.6'}
# {'_id': ObjectId('5cdec62df7a1b62d2a825447'), 'name': 'Augsburg', 'goals_scored': '36', 'total_wins': '8', 'total_losses': '12', 'raining_win_percentage': '0.36363636363636365'}
